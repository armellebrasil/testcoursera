# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# __Armelle Champetier__
#
# I am currently the founder and COO of Workally.

# %% [markdown]
# *I am interested in data science because I believe it is essential in my startup project, as I will need to hire and work with data scientist. I also think it's important to have notions of data science to understand our current world*

# %% [markdown]
# ### The code in the next cell display the result of a simple operation (2+2)

# %%
2+2
# Out:
# 4

# %% [markdown]
# * bulleted list
# * bulleted list
#
# 1. First ordered list item
# 2. Another item
#
# [Hyperlink](https://www.google.com)
#
# ~~strikethrough~~
